# %%
#Instalando a biblioteca
# !pip install -q cryptocmd

# %%
#Importando 
from cryptocmd import CmcScraper

# %%
#Definindo a moeda
scraper = CmcScraper("BTC")

# %%
#Requisição
dados_cripto = scraper.get_dataframe()

# %%
#Exibindo o dataframe
dados_cripto
# Out:
#            Date          Open          High           Low         Close  \
# 0    2024-04-10  69140.240643  71093.433161  67503.565613  70587.879439
# 1    2024-04-09  71632.502662  71742.506324  68212.919302  69139.015832
# 2    2024-04-08  69362.554005  72715.359609  69064.244898  71631.356946
# 3    2024-04-07  68897.111130  70284.426265  68851.630090  69362.551278
# 4    2024-04-06  67840.573581  69629.602049  67491.715235  68896.109984
# ...         ...           ...           ...           ...           ...
# 3996 2013-05-02    116.379997    125.599998     92.281898    105.209999
# 3997 2013-05-01    139.000000    139.889999    107.720001    116.989998
# 3998 2013-04-30    144.000000    146.929993    134.050003    139.000000
# 3999 2013-04-29    134.444000    147.488007    134.000000    144.539993
# 4000 2013-04-28    136.689455    143.365942    110.845593    127.954255
#
#             Volume    Market Cap                 Time Open  \
# ...
