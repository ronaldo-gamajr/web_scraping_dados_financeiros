# %%
# !pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 546.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/315.2 kB ? eta -:--:--
#      ----------- --------------------------- 92.2/315.2 kB 2.6 MB/s eta 0:00:01
#      ------------------ ------------------- 153.6/315.2 kB 1.5 MB/s eta 0:00:01
#      --------------------------- ---------- 225.3/315.2 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 315.2/315.2 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
import yfinance as yf

# %%
dados_empresas = yf.download("PETR4.SA")
dados_empresas
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2000-01-03   5.875000   5.875000   5.875000   5.875000   1.548671  35389440000
# 2000-01-04   5.550000   5.550000   5.550000   5.550000   1.463000  28861440000
# 2000-01-05   5.494000   5.494000   5.494000   5.494000   1.448238  43033600000
# 2000-01-06   5.475000   5.475000   5.475000   5.475000   1.443229  34055680000
# 2000-01-07   5.500000   5.500000   5.500000   5.500000   1.449819  20912640000
# ...               ...        ...        ...        ...        ...          ...
# 2024-04-05  37.900002  38.570000  37.169998  38.099998  38.099998     65469200
# 2024-04-08  38.029999  39.060001  37.730000  38.630001  38.630001     36384400
# 2024-04-09  38.900002  39.139999  38.060001  38.730000  38.730000     36989300
# 2024-04-10  38.730000  39.730000  38.660000  39.590000  39.590000     55821500
# ...

# %%
lista_empresas = ["PETR4.SA", "ITUB4.SA"]
lista_acoes = yf.download(lista_empresas)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
lista_acoes
# Out:
# Price       Adj Close                 Close                  High             \
# Ticker       ITUB4.SA   PETR4.SA   ITUB4.SA   PETR4.SA   ITUB4.SA   PETR4.SA
# Date
# 2000-01-03        NaN   1.548671        NaN   5.875000        NaN   5.875000
# 2000-01-04        NaN   1.463000        NaN   5.550000        NaN   5.550000
# 2000-01-05        NaN   1.448238        NaN   5.494000        NaN   5.494000
# 2000-01-06        NaN   1.443229        NaN   5.475000        NaN   5.475000
# 2000-01-07        NaN   1.449819        NaN   5.500000        NaN   5.500000
# ...               ...        ...        ...        ...        ...        ...
# 2024-04-05  32.730000  38.099998  32.730000  38.099998  32.990002  38.570000
# 2024-04-08  33.220001  38.630001  33.220001  38.630001  33.529999  39.060001
# 2024-04-09  33.570000  38.730000  33.570000  38.730000  33.630001  39.139999
# 2024-04-10  32.860001  39.590000  32.860001  39.590000  33.500000  39.730000
# ...
